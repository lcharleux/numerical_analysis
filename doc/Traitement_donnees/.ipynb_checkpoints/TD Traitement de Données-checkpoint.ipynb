# %%
# %load_ext autoreload
# %matplotlib nbagg
# %autoreload 2
import copy

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## MECA653: Traitement de donnée - Analyse de la base de donnée de la sécurité routière
#
# L'objectif ici est d'analyser les données fournies par le ministère de l'intérieure sur les accidents de la route resencés en 2016.
#
# Le Module Panda sera largement utilisé.

# %% [markdown]
# ##  Sources
# Lien vers data.gouv.fr :
# https://www.data.gouv.fr/fr/datasets/base-de-donnees-accidents-corporels-de-la-circulation/#_
#
# Documentation de la base de donnée :
# DATA/Description_des_bases_de_donnees_ONISR_-Annees_2005_a_2016.pdf

# %% [markdown]
# ## 1 - Charger les bases de donnée

# %%
dfc = pd.read_csv('./DATA/caracteristiques_2016.csv',index_col='Num_Acc')
dfu = pd.read_csv('./DATA/usagers_2016.csv',index_col='Num_Acc')
df = pd.concat([dfu, dfc], axis=1)

# %%
df.head()
# Out:
#               place  catu  grav  sexe  trajet  secu  locp  actp  etatp  \
# Num_Acc
# 201600000001    1.0     1     1     2     0.0  11.0   0.0   0.0    0.0
# 201600000001    1.0     1     3     1     9.0  21.0   0.0   0.0    0.0
# 201600000002    1.0     1     3     1     5.0  11.0   0.0   0.0    0.0
# 201600000002    2.0     2     3     1     0.0  11.0   0.0   0.0    0.0
# 201600000002    3.0     2     3     2     0.0  11.0   0.0   0.0    0.0
#
#               an_nais ...  agg  int  atm  col  com                  adr  gps  \
# Num_Acc               ...
# 201600000001   1983.0 ...    2    1    8  3.0    5   46, rue Sonneville    M
# 201600000001   2001.0 ...    2    1    8  3.0    5   46, rue Sonneville    M
# 201600000002   1960.0 ...    2    6    1  6.0    5  1a rue du cimetière    M
# 201600000002   2000.0 ...    2    6    1  6.0    5  1a rue du cimetière    M
# 201600000002   1962.0 ...    2    6    1  6.0    5  1a rue du cimetière    M
#
#               lat  long  dep
# Num_Acc
# 201600000001  0.0   0.0  590
# 201600000001  0.0   0.0  590
# 201600000002  0.0   0.0  590
# 201600000002  0.0   0.0  590
# 201600000002  0.0   0.0  590
#
# [5 rows x 26 columns]

# %% [markdown]
# ## 2 - Quelle est la poportion Homme/Femme impliquée dans les accidents ? Représenter le résultat sous forme graphique.

# %%
# methode pas propre
(h,c)=df[df.sexe==1].shape
(f,c)=df[df.sexe==2].shape

(t,c)=df.shape

print('h/t=', h/t)
print('f/t=', f/t)
# Out:
# h/t= 0.6999145568197149
# f/t= 0.3000854431802851

# %%
# methode panda
df["sexe"].value_counts(normalize=True)
# Out:
# 1    0.699915
# 2    0.300085
# Name: sexe, dtype: float64

# %%
df[df.grav==2].sexe.value_counts(normalize=True).plot.pie(labels=['Homme', 'Femme'], colors= ['r', 'g'], autopct='%.2f')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
df[df.grav==2].sexe
# Out:
# Num_Acc
# 201600000014    1
# 201600000022    1
# 201600000023    1
# 201600000025    1
# 201600000056    1
# 201600000058    2
# 201600000066    2
# 201600000069    1
# 201600000074    1
# 201600000078    1
# 201600000093    1
# 201600000095    2
# 201600000099    1
# 201600000099    2
# 201600000111    2
# 201600000118    1
# 201600000119    1
# 201600000120    2
# 201600000126    2
# 201600000129    1
# 201600000133    1
# 201600000137    1
# 201600000140    1
# 201600000155    1
# 201600000162    2
# 201600000164    1
# 201600000175    1
# 201600000178    1
# 201600000179    1
# 201600000181    1
#                ..
# 201600058365    1
# 201600058381    2
# 201600058402    1
# 201600058475    1
# 201600058515    1
# 201600058550    1
# 201600058890    1
# 201600058930    1
# 201600058955    1
# 201600059032    2
# 201600059036    1
# 201600059073    1
# 201600059075    1
# 201600059084    1
# 201600059085    1
# 201600059098    1
# 201600059106    1
# 201600059113    1
# 201600059115    2
# 201600059138    1
# 201600059164    1
# 201600059202    1
# 201600059213    1
# 201600059243    1
# 201600059304    1
# 201600059308    1
# 201600059339    2
# 201600059390    1
# 201600059406    1
# 201600059419    1
# Name: sexe, Length: 3655, dtype: int64

# %%
df[df.grav==2].sexe.value_counts(normalize=True)
#df.sexe.plot.pie()
# Out:
# 1    0.763338
# 2    0.236662
# Name: sexe, dtype: float64

# %%
df["lum"].value_counts(normalize=True)
# Out:
# 1    0.689272
# 5    0.157950
# 3    0.085623
# 2    0.058926
# 4    0.008230
# Name: lum, dtype: float64

# %%
df.sexe
